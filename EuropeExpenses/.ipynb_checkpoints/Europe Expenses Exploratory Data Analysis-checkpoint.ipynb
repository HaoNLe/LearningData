# %%
import matplotlib.pyplot as plt
import pandas as pd
my_colors = ['#4f94cd', '#eedc82', '#a4a4a4', '#ff7f50', '#54ff9f', '#dda0dd', '#f08080', '#48d1cc']

# %%
df = pd.read_csv("Europe_Expenses.csv")

# %%
df.head()
# Out:
#      ﻿Purchase       Date   Cost            Type  \
# 0  Oyster Card  3/19/2018   7.00  Transportation
# 1        Train  3/19/2018  11.62  Transportation
# 2     Padlock   3/19/2018   2.80            Misc
# 3       Hostel  3/19/2018  20.30         Housing
# 4  2 pint milk  3/20/2018   1.11       Groceries
#
#                                                Notes    City
# 0                                                NaN  London
# 1                           Gatwick to London Bridge  London
# 2  Not sure since I recorded this as a combinatio...  London
# 3                                                NaN  London
# 4                                                NaN  London

# %%
byType = df.groupby('Type').sum().sort_values('Cost', ascending=True)
byType
# Out:
#                    Cost
# Type
# Misc              31.74
# Alcohol           41.31
# Toiletries        75.84
# Groceries        218.71
# Recreation       221.69
# Transportation   676.18
# Eating Out       763.50
# Housing         1275.49

# %%
ax = byType.plot.bar(fontsize=12, color = my_colors, legend=False, edgecolor='None')

# %%
ax.spines['right'].set_color('None')
ax.spines['top'].set_color('None')
plt.tick_params(axis='x', which='both', top=False, bottom=False)
plt.tick_params(axis='y', which='both', right=False, left=False)
plt.show()

# %%
byDate = df.groupby('Date').sum()
byDate.head()
# Out:
#               Cost
# Date
# 2018-03-19   41.72
# 2018-03-20   81.88
# 2018-03-21   79.23
# 2018-03-22   74.56
# 2018-03-23  105.69

# %%
ax = byDate.plot.line(rot=0, fontsize=6, legend=False, title="Money Spent", color="#0B8E36")

# %%
ax.spines['right'].set_color('None')
ax.spines['top'].set_color('None')
plt.tick_params(axis='x', which='both', top=False)
plt.tick_params(axis='y', which='both', right=False)
plt.show()

# %%
byCity = df.groupby('City').sum().sort_values('Cost', ascending=True)
byCity.head()
# Out:
#              Cost
# City
# Budapest    88.03
# Amsterdam  102.57
# Utrecht    105.76
# Annecy     126.31
# Berlin     144.21

# %%
ax = byCity.plot.bar(fontsize=10, color ='#0B8E36', legend=False, title = 'Cost per city', edgecolor='None')
ax.spines['right'].set_color('None')
ax.spines['top'].set_color('None')
plt.tick_params(axis='x', which='both', top=False, bottom=False)
plt.tick_params(axis='y', which='both', right=False, left=False)

# %%
plt.show()

# %%
byCityDate = df.groupby(['City', 'Date']).sum()
byCityDate.head()
# Out:
#                        Cost
# City      Date
# Amsterdam 2018-04-09  26.00
#           2018-04-10  64.48
#           2018-04-15  12.09
# Annecy    2018-03-29  65.13
#           2018-03-30  61.18

# %%
byCityDateAvg = byCityDate.groupby(level=[0]).mean().sort_values('Cost', ascending=True)
byCityDateAvg = byCityDateAvg.rename(index=str, columns={"Cost": "Avg Daily Cost"})
byCityDateAvg.head()
# Out:
#            Avg Daily Cost
# City
# Utrecht           21.1520
# Amsterdam         34.1900
# Lyon              38.1625
# Prague            41.8700
# Budapest          44.0150

# %%
ax = byCityDateAvg.plot.bar(fontsize=10, color ='#0B8E36', legend=False, title = 'Avg daily cost per city', edgecolor = "none")
ax.spines['right'].set_color('None')
ax.spines['top'].set_color('None')
plt.tick_params(axis='x', which='both', top=False, bottom=False)
plt.tick_params(axis='y', which='both', right=False, left=False)
plt.show()

# %%
df.head()
# Out:
#      ﻿Purchase        Date   Cost            Type  \
# 0  Oyster Card  2018-03-19   7.00  Transportation
# 1        Train  2018-03-19  11.62  Transportation
# 2     Padlock   2018-03-19   2.80            Misc
# 3       Hostel  2018-03-19  20.30         Housing
# 4  2 pint milk  2018-03-20   1.11       Groceries
#
#                                                Notes    City
# 0                                                NaN  London
# 1                           Gatwick to London Bridge  London
# 2  Not sure since I recorded this as a combinatio...  London
# 3                                                NaN  London
# 4                                                NaN  London

# %%
#df['Date'] = df['Date'].dt.date
df2 = df.groupby(['Date', 'Type'])['Cost'].sum().unstack('Type')
oldCols = df2.columns.tolist()
newCols = [oldCols[3], oldCols[1], oldCols[7], oldCols[5], oldCols[2], oldCols[6], oldCols[0], oldCols[4]]
df3 = df2[newCols]
ax = df3.plot.bar(fontsize=10, figsize=(20,10), stacked=True, title='Cost Breakdown per Day', color = my_colors, edgecolor="None")

# %%
ax.spines['right'].set_color('None')
ax.spines['top'].set_color('None')
plt.tick_params(axis='x', which='both', top=False, bottom=False)
plt.tick_params(axis='y', which='both', right=False, left=True)
plt.show()

# %%
df4 = df.groupby(['City', 'Type'])['Cost'].sum().unstack('Type')
oldCols = df4.columns.tolist()
newCols = [oldCols[3], oldCols[1], oldCols[7], oldCols[5], oldCols[2], oldCols[6], oldCols[0], oldCols[4]]
df4 = df4[newCols]
ax = df4.plot.bar(fontsize=16, figsize=(20,10), stacked=True, title = 'Cost Breakdown per City', color=my_colors, edgecolor="None");

# %%
ax.spines['right'].set_color('None')
ax.spines['top'].set_color('None')
plt.tick_params(axis='x', which='both', top=False, bottom=False)
plt.tick_params(axis='y', which='both', right=False, left=True)
plt.show()
